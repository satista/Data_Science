# %%
# Out:
# Here is a description of the data frame dt1 and number of lines
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      68 non-null     datetime64[ns]
#  1   Set_Num_Drumline          68 non-null     object
#  2   Num_Hooks_Drumline        68 non-null     object
#  3   Set_Start_Time            68 non-null     datetime64[ns]
#  4   Season                    68 non-null     category
#  5   SITENAME                  68 non-null     object
#  6   Latitude_DD               68 non-null     object
#  7   Longitude_DD              68 non-null     object
#  8   River_KMs                 68 non-null     float64
#  9   Depth                     49 non-null     float64
#  10  WaterTemp                 65 non-null     float64
#  11  Salinity                  64 non-null     float64
# ...
